# %% [markdown]
# <a href="https://colab.research.google.com/github/BioBarto/BioinformatykaRoslin2021/blob/main/Program.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print ("hello word")
# Out:
# hello word

# %% [markdown]
# ## Wczytanie zbioru danych z użyciem biblioteki pandas
# ###OUTPUT:
# data_pd

# %%
import pandas as pd
path_to_data = "https://raw.githubusercontent.com/BioBarto/BioinformatykaRoslin2021/main/data_all.txt"
data_pd = pd.read_csv(path_to_data)

# %%
data.head()
# Out:
#    grain_yield  pht_height  Heading_Date  ...  SNP_2316  SNP_2317  SNP_2318
# 0         4869          78          57.5  ...         1        -1        -1
# 1         4621          74          56.0  ...         1        -1         1
# 2         4557          66          58.0  ...         1        -1         1
# 3         5484          77          59.0  ...         1        -1        -1
# 4         4641          69          55.5  ...         1        -1        -1
#
# [5 rows x 2321 columns]

# %% [markdown]
# ## Wczytanie zbioru danych z użyciem biblioteki import.url
# ###OUTPUT:
# data_url

# %%
import urllib.request  # the lib that handles the url stuff
url = "https://raw.githubusercontent.com/BioBarto/BioinformatykaRoslin2021/main/data_all.txt"
file = urllib.request.urlopen(url)

data_url = []
for line in urllib.request.urlopen(url):
    data_url.append(line.decode('utf-8'))

# %%
data.head()
# Out:
#    grain_yield  pht_height  Heading_Date  ...  SNP_2316  SNP_2317  SNP_2318
# 0         4869          78          57.5  ...         1        -1        -1
# 1         4621          74          56.0  ...         1        -1         1
# 2         4557          66          58.0  ...         1        -1         1
# 3         5484          77          59.0  ...         1        -1        -1
# 4         4641          69          55.5  ...         1        -1        -1
#
# [5 rows x 2321 columns]

# %% [markdown]
# ## KOD potrzebny do ANALIZY zbioru

# %%
#Różnice pomiędzy data_url / data_pd

print(type(data_url))
print(type(data_pd))
# Out:
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>

# %%
#Określam zmieną data - jako listę (nie jako macierz z biblioteki Panda)
data = data_pd
